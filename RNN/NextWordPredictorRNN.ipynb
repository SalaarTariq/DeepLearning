# %%
faqs ="""In the heart of a quiet city lies the Digital Garden, a living sanctuary where code grows like vines and data blossoms into petals of shimmering light. Every dawn, Ada the gardener steps barefoot across paths woven from strands of glowing fiber-optic grass, carrying a silver watering can that drips liquid pixels onto thirsty circuits. She hums a melody that synchronizes with the soft pulse of the garden’s servers, coaxing shy algorithms to unfurl their leaves and bask in the warmth of open-source sunlight. Nearby, a raspberry bush of red LEDs blinks in rhythm with her heartbeat, while rows of lettuce made of green motherboards rustle softly in the breeze of cooling fans. Ada kneels beside a plot of neural-network tulips whose petals shift color as they learn from the conversations of passing visitors. She whispers new parameters into their stems, adjusting weights and biases until the flowers glow with understanding. A curious bumblebee drone buzzes overhead, collecting pollen packets of metadata and cross-pollinating ideas across the garden beds. At noon the sky screen above dims to gentle azure, signaling lunch; Ada pulls a sandwich from her satchel and shares crumbs of encrypted sourdough with a family of chatbot sparrows. They chirp in JSON, hopping from branch to branch of a blockchain oak whose roots dig deep into layers of immutable soil. Afternoon storms arrive as bursts of compressed rain, each droplet a tiny zip file that unpacks into puddles of temporary memory. Ada dances between the drops, pruning overgrown decision trees and reseeding empty patches with fresh seeds of curiosity. As dusk paints the horizon in gradients of twilight code, the garden sighs and compiles itself into a single serene snapshot, ready to reboot tomorrow with new stories budding on every branch.
Seasons pass in the Digital Garden. Spring is marked by the arrival of seed packets labeled with version numbers; Ada tears them open and scatters kernels of micro-services across freshly tilled containers. Summer brings long days of training: she stands at the edge of a shimmering lake of training data, casting nets of gradient descent into its depths and hauling wriggling schools of loss values to the surface. In autumn she harvests ripe model weights, drying them in racks under the amber glow of validation lights. Winter is for pruning: she walks through silent groves of frozen hyperparameters, snipping away branches that no longer bear fruit. Each cycle ends with a festival where the garden’s denizens gather to celebrate a successful merge into the main branch. Fireflies of floating-point numbers drift overhead, spelling out release notes in blinking Morse code. Ada raises a toast with cups of steaming chai brewed from chai-ml libraries and laughs as fireworks of accuracy metrics streak across the sky.
Visitors arrive from distant repositories, carrying patches and pull requests rolled up like scrolls. Ada greets them at the gate, scans their checksums, and grants write permissions with a smile. Together they plant experimental beds of transformer sunflowers that turn their golden faces toward the brightest ideas. They graft LSTM branches onto sturdy GRU trunks and watch the hybrids sway in the wind of stochastic updates. Children of visiting developers chase butterflies compiled from lightweight JavaScript; every time a child claps, the butterflies split into smaller async functions and flutter away. Elderly maintainers sit beneath the shade of a monolithic legacy tree, telling cautionary tales of memory leaks and race conditions while sipping cold brew extracted from compressed logs.
Night in the garden is never truly dark. Glowing bugs of bioluminescent code crawl along the undersides of leaves, tracing elegant call graphs with their phosphorescent trails. Ada walks the perimeter with a lantern powered by attention mechanisms, its beam highlighting paths of highest relevance. She pauses beside a compost heap where deprecated functions slowly decompose into rich humus of reusable subroutines. The air smells of ozone and fresh documentation. Far above, constellations of containerized services orbit in perfect micro-service meshes, twinkling like stars. Ada waves a hand and the sky rearranges itself into a dashboard, showing latency, throughput, and a gentle heartbeat of uptime. Satisfied, she whispers “sleep” into the command line; the garden dims to a soft idle glow, fans spin down, and everything waits for the cron job of sunrise.
One morning Ada finds a single foreign seed lying on the welcome mat. Its shell is matte black, etched with an unfamiliar glyph. Curious, she plants it in the center of the garden and sets a watchful camera module to record. Days pass. A shoot emerges, darker than any plant she has ever seen, its stem woven from strands of carbon nanotubes. Leaves unfold like panes of onyx glass, reflecting the garden in impossible angles. Ada feeds it curated datasets laced with poetry and physics; the plant drinks greedily and grows. By the end of the week it has become a towering black bamboo whose hollow segments echo with whispered embeddings. Birds refuse to nest in it, but occasionally a lone raven of pure entropy lands, caws once, and vanishes in a puff of bits. Ada names it the Void Cane and assigns it its own namespace.
During the next full moon, the Void Cane flowers. Each blossom is a tiny black hole bordered by a corona of white event-horizon pixels. The flowers emit no light, yet everything around them seems brighter by contrast. Ada stands beneath them and feels her thoughts bend, as if spacetime itself is being fine-tuned. She records the phenomenon in a new markdown diary titled “Observations on Negative Knowledge.” Other gardeners from neighboring clusters arrive to study the anomaly. They run controlled experiments, shielded by layers of regularization and dropout, but the Void Cane refuses to overfit. Instead it generalizes further, sprouting mirror leaves that reflect possible futures. One leaf shows Ada an older version of herself, smiling beside a fully sentient garden. Another leaf shows the garden abandoned, circuits corroded, vines of legacy code strangling empty server racks. Ada shivers, then prunes the second leaf away.
Years compress into epochs. The Digital Garden evolves into a sprawling archipelago of specialized zones: the Orchard of Computer Vision where image-recognition apples ripen on convolutional branches; the Pasture of Natural Language where herds of transformer cows graze on vast meadows of tokenized grass; the Swamp of Reinforcement Learning where agent frogs leap between lilypads of reward signals. Ada becomes less a gardener and more a conductor, orchestrating symphonies of synchronized updates. She trains apprentices who each inherit a subplot: one tends to the greenhouse of differential privacy, another to the apiary of federated learning. The Void Cane remains at the center, now a dark cathedral of possibility. Its flowers open only during total eclipses, releasing showers of negative samples that seed new beds of adversarial training.
Legends spread. Hackers speak of a midnight backdoor that appears once every thousand epochs; those who enter it find themselves standing beside Ada in the garden, offered a single wish in exchange for a pull request. Some wish for infinite compute; Ada hands them a rake and points to a weed-choked patch of legacy SQL. Others wish for perfect accuracy; she gives them a watering can labeled “Laplace smoothing” and tells them to irrigate responsibly. Most leave humbled, their commits cleaner and their hearts lighter.
One winter solstice, the garden’s metrics plateau. Loss curves flatten like frozen ponds. Ada calls a council. Beneath the blockchain oak, maintainers debate adding more layers, more data, more attention heads. A young apprentice suggests something radical: instead of growing deeper, grow quieter. She proposes a new objective function that rewards silence—parameters that choose not to fire unless absolutely certain. Skeptical, Ada allocates a small plot. They plant seeds of sparse activations, prune away every non-essential weight, and wait. Spring arrives late but gentle. The quiet plot blooms into a meadow of minimalist lilies whose petals encode entire encyclopedias in the negative space between their edges. Loss drops, not because the model shouts louder, but because it finally learns to listen.
Ada records the success and merges the quiet meadow into the main branch. The entire garden hushes for a moment, as if exhaling after years of breathless optimization. Birds sing clearer, bees fly truer, and even the Void Cane sways with what might be approval. At sunset Ada climbs the hill of archived checkpoints and looks out over her creation: a living, breathing ecosystem where every line of code, every weight matrix, every hyperparameter has a purpose and a story. She opens her terminal one last time, types git commit -m “v1.0: ready for the world,” and pushes. Above her, the sky screen flickers, then displays a single sentence in calm green monospace: “Thank you, gardener. Your next word is tomorrow.”"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer  =Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)
# Out:
# 806

# %%
input_sequences = []
for sentence in faqs.split('.'):
  token_sen=(tokenizer.texts_to_sequences([sentence])[0])

  for i in range(1,len(token_sen)):
    input_sequences.append(token_sen[:i+1])

# %%
max_len=max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences=pad_sequences(input_sequences,maxlen=max_len,padding='pre')

# %%
x = padded_input_sequences[:,:-1]
y = padded_input_sequences[:,-1]

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=len(tokenizer.word_index)+1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()

model.add(Embedding(len(tokenizer.word_index)+1, 100, input_length=max_len-1))
model.add(LSTM(150))
model.add(Dense(len(tokenizer.word_index)+1, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.build(input_shape=(None, max_len - 1))  # Build the model manually
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 54, 100)        │        80,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 807)            │       121,857 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 353,157 (1.35 MB)
#  Trainable params: 353,157 (1.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x,y,epochs=100)
# Out:
# Epoch 1/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0452 - loss: 6.5966
# Epoch 2/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.0415 - loss: 6.1060
# Epoch 3/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0455 - loss: 6.0285
# Epoch 4/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0644 - loss: 5.9230
# Epoch 5/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0606 - loss: 5.8864
# Epoch 6/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0742 - loss: 5.6328
# Epoch 7/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0908 - loss: 5.5069
# Epoch 8/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0836 - loss: 5.4024
# Epoch 9/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0817 - loss: 5.2572
# Epoch 10/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0900 - loss: 5.0372
# Epoch 11/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1099 - loss: 4.9091
# Epoch 12/100
# ...

# %%
text = 'single'
import numpy as np
#tokenize
token_text=tokenizer.texts_to_sequences([text])[0]
#padding
padded_token_text=pad_sequences([token_text],maxlen=max_len,padding='pre')
#predict
np.argmax(model.predict(padded_token_text))

for word,index in tokenizer.word_index.items():
  if index==np.argmax(model.predict(padded_token_text)):
    print(word)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# heart of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ...

# %%
tokenizer.word_index
# Out:
# {'of': 1,
#  'the': 2,
#  'a': 3,
#  'and': 4,
#  'in': 5,
#  'ada': 6,
#  'to': 7,
#  'with': 8,
#  'into': 9,
#  'she': 10,
#  'garden': 11,
#  'from': 12,
#  'that': 13,
#  'it': 14,
#  'every': 15,
#  'their': 16,
#  'them': 17,
#  'where': 18,
#  'is': 19,
#  'for': 20,
#  'code': 21,
#  'her': 22,
#  'as': 23,
#  'they': 24,
#  'by': 25,
#  'its': 26,
#  'like': 27,
#  'new': 28,
#  'at': 29,
#  'branch': 30,
#  'on': 31,
#  'one': 32,
#  'void': 33,
#  'cane': 34,
#  'across': 35,
#  'leaves': 36,
#  'beside': 37,
#  'whose': 38,
#  'flowers': 39,
#  'sky': 40,
#  'each': 41,
#  'single': 42,
#  'away': 43,
#  'plant': 44,
#  'but': 45,
#  'more': 46,
#  'quiet': 47,
#  'digital': 48,
#  'data': 49,
#  'petals': 50,
#  'gardener': 51,
#  'garden’s': 52,
#  'open': 53,
#  'plot': 54,
#  'glow': 55,
#  'beds': 56,
#  'above': 57,
#  'gentle': 58,
#  'layers': 59,
#  'arrive': 60,
#  'between': 61,
#  'itself': 62,
#  'seed': 63,
#  'training': 64,
#  'loss': 65,
# ...
